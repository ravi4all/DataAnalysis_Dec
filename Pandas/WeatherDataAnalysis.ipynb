# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('data/rainfall_india.csv')

# %%
dataset.head()
# Out:
#                  STATE_UT_NAME       DISTRICT    JAN   FEB    MAR    APR  \
# 0  ANDAMAN And NICOBAR ISLANDS        NICOBAR  107.3  57.9   65.2  117.0
# 1  ANDAMAN And NICOBAR ISLANDS  SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2  ANDAMAN And NICOBAR ISLANDS  N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3            ARUNACHAL PRADESH          LOHIT   42.2  80.8  176.4  358.5
# 4            ARUNACHAL PRADESH     EAST SIANG   33.3  79.5  105.9  216.5
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  \
# 0  358.5  295.5  285.0  271.9  354.8  326.0  315.2  250.9  2805.2    165.2
# 1  374.4  457.2  421.3  423.1  455.6  301.2  275.8  128.3  3015.7     69.7
# 2  343.6  503.3  465.4  460.9  454.8  276.1  198.6  100.0  2913.3     48.6
# 3  306.4  447.0  660.1  427.8  313.6  167.1   34.1   29.8  3043.8    123.0
# 4  323.0  738.3  990.9  711.2  568.0  206.9   29.5   31.7  4034.7    112.8
#
#    Mar-May  Jun-Sep  Oct-Dec
# 0    540.7   1207.2    892.1
# ...

# %%
dataset.sort_index(axis = 1, ascending=False)
# Out:
#                    STATE_UT_NAME    SEP  Oct-Dec    OCT    NOV  Mar-May  \
# 0    ANDAMAN And NICOBAR ISLANDS  354.8    892.1  326.0  315.2    540.7
# 1    ANDAMAN And NICOBAR ISLANDS  455.6    705.3  301.2  275.8    483.5
# 2    ANDAMAN And NICOBAR ISLANDS  454.8    574.7  276.1  198.6    405.6
# 3              ARUNACHAL PRADESH  313.6    231.0  167.1   34.1    841.3
# 4              ARUNACHAL PRADESH  568.0    268.1  206.9   29.5    645.4
# 5              ARUNACHAL PRADESH  159.8    108.4   75.9   20.9    327.3
# 6              ARUNACHAL PRADESH  418.3    284.5  218.7   42.9    786.6
# 7              ARUNACHAL PRADESH  313.6    231.0  167.1   34.1    841.3
# 8              ARUNACHAL PRADESH  266.7    287.2  167.2   64.0    955.1
# 9              ARUNACHAL PRADESH  353.6    414.1  275.0   64.9   1256.5
# 10             ARUNACHAL PRADESH  492.3    245.2  214.7   19.2    786.0
# 11             ARUNACHAL PRADESH  192.7    155.2   78.5   49.5    562.9
# ...

# %%
dataset.sort_values(by = 'JAN')
# Out:
#                    STATE_UT_NAME       DISTRICT    JAN    FEB    MAR    APR  \
# 463                      GUJARAT          SURAT    0.0    0.1    0.9    0.1
# 470                      GUJARAT      TAPI(SRT)    0.0    0.0    0.8    0.1
# 484                  MAHARASHTRA      RATNAGIRI    0.1    0.0    0.1    3.5
# 483                  MAHARASHTRA         RAIGAD    0.2    0.2    0.1    1.8
# 477                      GUJARAT  SURENDRANAGAR    0.2    0.0    0.1    0.3
# 485                  MAHARASHTRA          THANE    0.2    0.3    0.3    0.7
# 476                      GUJARAT         RAJKOT    0.3    0.0    0.9    0.4
# 596                    KARNATAKA  UTTAR KANNADA    0.3    0.1    2.7   22.1
# 486                  MAHARASHTRA     SINDHUDURG    0.3    0.1    0.4    4.3
# 456                      GUJARAT        BHARUCH    0.3    0.1    0.8    0.1
# 608                    KARNATAKA         HAVERI    0.3    0.5    4.0   43.6
# ...

# %%
dataset[dataset['STATE_UT_NAME'] == 'GUJARAT']
# Out:
#     STATE_UT_NAME       DISTRICT  JAN  FEB  MAR  APR   MAY    JUN    JUL  \
# 453       GUJARAT      AHMEDABAD  0.8  0.3  0.5  0.7   5.9   91.0  215.4
# 454       GUJARAT    BANASKANTHA  1.4  1.3  2.4  0.9   3.7   63.4  220.0
# 455       GUJARAT         BARODA  1.2  0.0  0.5  0.8   4.6  138.8  332.5
# 456       GUJARAT        BHARUCH  0.3  0.1  0.8  0.1   4.9  135.4  283.2
# 457       GUJARAT         VALSAD  0.7  0.1  0.5  0.0   6.3  350.5  771.8
# 458       GUJARAT          DANGS  1.5  1.0  1.4  3.4  12.5  258.6  749.8
# 459       GUJARAT          KHEDA  1.2  0.4  1.3  0.4   4.5  110.3  291.0
# 460       GUJARAT        MEHSANA  1.3  0.6  1.0  1.0   5.7   73.9  248.2
# 461       GUJARAT    PANCHMAHALS  1.0  0.1  0.7  0.3   6.0  114.5  311.5
# 462       GUJARAT    SABARKANTHA  1.1  0.6  2.3  1.4   4.5   89.1  289.0
# 463       GUJARAT          SURAT  0.0  0.1  0.9  0.1   5.4  223.4  495.7
# 464       GUJARAT    GANDHINAGAR  0.9  0.6  0.7  0.4   6.8   72.3  280.6
# ...

# %%
dates = pd.date_range('20130101', periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.read_csv('data/rdu-weather-history.csv')

# %%
df.head()
# Out:
#          date  temperaturemin  temperaturemax  precipitation  snowfall  \
# 0  2009-10-03            55.0            82.0           0.00       0.0
# 1  2009-10-10            59.0            79.0           0.02       0.0
# 2  2009-10-14            46.9            61.0           0.14       0.0
# 3  2009-10-17            45.0            57.9           0.00       0.0
# 4  2009-10-29            48.0            68.0           0.00       0.0
#
#    snowdepth  avgwindspeed  fastest2minwinddir  fastest2minwindspeed  \
# 0        0.0          2.91               240.0                 16.11
# 1        0.0          7.83               220.0                 17.00
# 2        0.0          8.72                40.0                 14.99
# 3        0.0          6.26                30.0                 14.09
# 4        0.0          5.82                80.0                 14.99
#
#    fastest5secwinddir     ...      drizzle snow freezingrain smokehaze  \
# ...

# %%
dates = df.date

# %%
df.index = dates

# %%
df.loc[dates[0]]
# Out:
# date                    2009-10-03
# temperaturemin                  55
# temperaturemax                  82
# precipitation                    0
# snowfall                         0
# snowdepth                        0
# avgwindspeed                  2.91
# fastest2minwinddir             240
# fastest2minwindspeed         16.11
# fastest5secwinddir             230
# fastest5secwindspeed         19.91
# fog                            Yes
# fogheavy                        No
# mist                            No
# rain                            No
# fogground                       No
# ice                             No
# glaze                           No
# drizzle                         No
# snow                            No
# freezingrain                    No
# smokehaze                       No
# thunder                         No
# highwind                        No
# hail                            No
# blowingsnow                     No
# dust                            No
# ...

# %%
dataset.iloc[0]
# Out:
# STATE_UT_NAME    ANDAMAN And NICOBAR ISLANDS
# DISTRICT                             NICOBAR
# JAN                                    107.3
# FEB                                     57.9
# MAR                                     65.2
# APR                                      117
# MAY                                    358.5
# JUN                                    295.5
# JUL                                      285
# AUG                                    271.9
# SEP                                    354.8
# OCT                                      326
# NOV                                    315.2
# DEC                                    250.9
# ANNUAL                                2805.2
# Jan-Feb                                165.2
# Mar-May                                540.7
# Jun-Sep                               1207.2
# Oct-Dec                                892.1
# Name: 0, dtype: object
