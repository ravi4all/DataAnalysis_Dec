# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
ts.head()
# Out:
# 2000-01-01    1.183062
# 2000-01-02   -1.969305
# 2000-01-03    1.440490
# 2000-01-04    1.642642
# 2000-01-05    0.701303
# Freq: D, dtype: float64

# %%
ts.shape
# Out:
# (1000,)

# %%
ts.plot()

# %%
ts.to_csv('dates_data.csv')
